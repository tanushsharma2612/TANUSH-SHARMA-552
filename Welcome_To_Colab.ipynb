# %% [markdown]
# <a href="https://colab.research.google.com/github/tanushsharma2612/TANUSH-SHARMA-552/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 10

# %%
mysub = "python"
mysub
# Out:
# 'python'

# %%
print(mysub)
# Out:
# python

# %%
_mycity = "solan"
print(_mycity)
# Out:
# solan

# %%
my_sub1 = "Generative AI"
print(my_sub1)
# Out:
# Generative AI

# %%
1my_sub = "science"
print(1my_sub)
# Out:
#   File "/tmp/ipython-input-45333540.py", line 1
#     1my_sub = "science"
#     ^
# SyntaxError: invalid decimal literal

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
x = 0
type(x)
# Out:
# int

# %%
y = 1.0
type(y)
# Out:
# float

# %%
z = 3+4j
type(z)
# Out:
# complex

# %%
#string --data in the form
a = "solan"
type(a)
# Out:
# str

# %%
#boolean -- it is used to store value in the form of true or false
a = True
type(a)
# Out:
# bool

# %%
#none -- it is define value means nothing
e = None
type (e)
# Out:
# NoneType

# %%
#single quotes
my_sub = "generative AI"
type(my_sub)
# Out:
# str

# %%
#double quotes
my_sub = 'Generative AI'
type(my_sub)
# Out:
# str

# %%
#double quotes
my_college = "shoolini university"
type(my_college)
# Out:
# str

# %%
#triple quotes
my_sentence = ''' this sentence is multiplied lines,this is also a string'''
type(my_sentence)
# Out:
# str

# %%
#find length of string
my_sub = "machine learning"
len(my_sub)
# Out:
# 16

# %%
my_sub[0]
# Out:
# 'm'

# %%
my_sub[-16]
# Out:
# 'm'

# %%
my_sub[-1]
# Out:
# 'g'

# %%
my_sub[4]
# Out:
# 'i'

# %%
my_sub
# Out:
# 'machine learning'

# %%
my_sub[0:7:1]
# Out:
# 'machine'

# %%
#concatenation--adding the string
first_name = "Amit"
last_name = "kumar"
full_name = first_name +" "+last_name
print(full_name)
# Out:
# Amit kumar

# %%
lower(my_sub)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3174124106.py in <cell line: 0>()
# ----> 1 lower(my_sub)
#
# NameError: name 'lower' is not defined

# %%
#upper()--this method convert string into upper case
my_sub.upper()
# Out:
# 'MACHINE LEARNING'

# %%
#count()--count particulat character of the string
my_sub = "machine learning"
my_sub.count("a")
# Out:
# 2

# %%
#list--it is sequence of item ,every item seperate by comma
#in list all item are enclosed by squarebracket
my_list = [98,34,56,"apple", true]
print(my_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2528434839.py in <cell line: 0>()
#       1 #list--it is sequence of item ,every item seperate by comma
#       2 #in list all item are enclosed by squarebracket
# ----> 3 my_list = [98,34,56,"apple", true]
#       4 print(my_list)
#
# NameError: name 'true' is not defined
